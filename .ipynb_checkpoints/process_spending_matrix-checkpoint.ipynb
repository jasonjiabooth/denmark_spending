# %%
import pandas as pd
from pathlib import Path

# %%
# Part 1: Convert spending matrix from wide to long

# %%
df = pd.read_excel(r"C:\Users\jasonjia\Dropbox\Projects\denmark_spending\data\spending_matrix.xlsx")

# %%
df.shape
# Out:
# (2400, 1003)

# %%
df.head()
# Out:
#   cust_muni      cust_sector            cust_cell  s_s01_spendinflow_101  \
# 0       101  s01_spendinflow  s01_spendinflow_101             51469948.0
# 1       101  s02_spendinflow  s02_spendinflow_101             25137598.0
# 2       101  s03_spendinflow  s03_spendinflow_101             11569621.0
# 3       101  s04_spendinflow  s04_spendinflow_101             78666368.0
# 4       101  s05_spendinflow  s05_spendinflow_101              9757826.0
#
#    s_s01_spendinflow_147  s_s01_spendinflow_151  s_s01_spendinflow_153  \
# 0           3.048433e+06          162336.375000          111463.296875
# 1           1.886226e+06           99240.820312           71970.523438
# 2           8.951118e+05           70801.500000           73170.500000
# 3           5.303830e+06          329692.468750          493105.562500
# 4           6.021018e+05           96816.023438           75285.585938
#
#    s_s01_spendinflow_155  s_s01_spendinflow_157  s_s01_spendinflow_159  ...  \
# 0           50868.199219           5.954234e+05          125066.648438  ...
# 1           41274.871094           4.207714e+05           97837.468750  ...
# 2           14520.179688           2.219874e+05           80327.843750  ...
# 3          177316.531250           1.716689e+06          758979.312500  ...
# 4           38036.179688           2.431226e+05          118268.843750  ...
#
#    s_s10_spendinflow_810  s_s10_spendinflow_813  s_s10_spendinflow_820  \
# 0                    NaN            8310.788086                    NaN
# 1                    NaN           18541.515625                    NaN
# 2                    NaN            3646.535889                    NaN
# 3            4900.304688           70766.835938            3599.186523
# 4                    NaN           13956.801758                    NaN
#
#    s_s10_spendinflow_825  s_s10_spendinflow_840  s_s10_spendinflow_846  \
# 0                    NaN            5474.520508            4838.220215
# 1            3895.310059            7172.877441           11397.343750
# 2                    NaN                    NaN                    NaN
# 3            2867.418213           19103.824219           68593.648438
# 4                    NaN                    NaN                    NaN
#
#    s_s10_spendinflow_849  s_s10_spendinflow_851  s_s10_spendinflow_860  \
# 0                    NaN           63462.484375            5270.793457
# 1            4184.443359           68098.156250            7582.768555
# 2                    NaN            9108.286133            5568.153320
# 3           14702.837891          141515.453125           49023.187500
# 4                    NaN           19278.945312                    NaN
#
#    s_s10_spendinflow_foreign
# 0               8.662524e+05
# 1               7.817341e+05
# 2               2.798740e+05
# 3               2.783683e+06
# 4               4.274029e+05
#
# [5 rows x 1003 columns]

# %%
df.columns
# Out:
# Index(['cust_muni', 'cust_sector', 'cust_cell', 's_s01_spendinflow_101',
#        's_s01_spendinflow_147', 's_s01_spendinflow_151',
#        's_s01_spendinflow_153', 's_s01_spendinflow_155',
#        's_s01_spendinflow_157', 's_s01_spendinflow_159',
#        ...
#        's_s10_spendinflow_810', 's_s10_spendinflow_813',
#        's_s10_spendinflow_820', 's_s10_spendinflow_825',
#        's_s10_spendinflow_840', 's_s10_spendinflow_846',
#        's_s10_spendinflow_849', 's_s10_spendinflow_851',
#        's_s10_spendinflow_860', 's_s10_spendinflow_foreign'],
#       dtype='object', length=1003)

# %%
df.rename(columns = {'cust_muni':'spender_region', 'cust_sector':'spender_sector','cust_cell':'spender_sector_region'}, inplace = True)

# %%
df.head()
# Out:
#   spender_region   spender_sector spender_sector_region  \
# 0            101  s01_spendinflow   s01_spendinflow_101
# 1            101  s02_spendinflow   s02_spendinflow_101
# 2            101  s03_spendinflow   s03_spendinflow_101
# 3            101  s04_spendinflow   s04_spendinflow_101
# 4            101  s05_spendinflow   s05_spendinflow_101
#
#    s_s01_spendinflow_101  s_s01_spendinflow_147  s_s01_spendinflow_151  \
# 0             51469948.0           3.048433e+06          162336.375000
# 1             25137598.0           1.886226e+06           99240.820312
# 2             11569621.0           8.951118e+05           70801.500000
# 3             78666368.0           5.303830e+06          329692.468750
# 4              9757826.0           6.021018e+05           96816.023438
#
#    s_s01_spendinflow_153  s_s01_spendinflow_155  s_s01_spendinflow_157  \
# 0          111463.296875           50868.199219           5.954234e+05
# 1           71970.523438           41274.871094           4.207714e+05
# 2           73170.500000           14520.179688           2.219874e+05
# 3          493105.562500          177316.531250           1.716689e+06
# 4           75285.585938           38036.179688           2.431226e+05
#
#    s_s01_spendinflow_159  ...  s_s10_spendinflow_810  s_s10_spendinflow_813  \
# 0          125066.648438  ...                    NaN            8310.788086
# 1           97837.468750  ...                    NaN           18541.515625
# 2           80327.843750  ...                    NaN            3646.535889
# 3          758979.312500  ...            4900.304688           70766.835938
# 4          118268.843750  ...                    NaN           13956.801758
#
#    s_s10_spendinflow_820  s_s10_spendinflow_825  s_s10_spendinflow_840  \
# 0                    NaN                    NaN            5474.520508
# 1                    NaN            3895.310059            7172.877441
# 2                    NaN                    NaN                    NaN
# 3            3599.186523            2867.418213           19103.824219
# 4                    NaN                    NaN                    NaN
#
#    s_s10_spendinflow_846  s_s10_spendinflow_849  s_s10_spendinflow_851  \
# 0            4838.220215                    NaN           63462.484375
# 1           11397.343750            4184.443359           68098.156250
# 2                    NaN                    NaN            9108.286133
# 3           68593.648438           14702.837891          141515.453125
# 4                    NaN                    NaN           19278.945312
#
#    s_s10_spendinflow_860  s_s10_spendinflow_foreign
# 0            5270.793457               8.662524e+05
# 1            7582.768555               7.817341e+05
# 2            5568.153320               2.798740e+05
# 3           49023.187500               2.783683e+06
# 4                    NaN               4.274029e+05
#
# [5 rows x 1003 columns]

# %%
id_vars = ['spender_region', 'spender_sector', 'spender_sector_region']

# %%
df_new = pd.melt(df, id_vars=id_vars, var_name='recipient_sector_region', value_name='spend')
df_new
# Out:
#         spender_region     spender_sector      spender_sector_region  \
# 0                  101    s01_spendinflow        s01_spendinflow_101
# 1                  101    s02_spendinflow        s02_spendinflow_101
# 2                  101    s03_spendinflow        s03_spendinflow_101
# 3                  101    s04_spendinflow        s04_spendinflow_101
# 4                  101    s05_spendinflow        s05_spendinflow_101
# ...                ...                ...                        ...
# 2399995        foreign  s20_nospendinflow  s20_nospendinflow_foreign
# 2399996        foreign  s21_nospendinflow  s21_nospendinflow_foreign
# 2399997        foreign  s22_nospendinflow  s22_nospendinflow_foreign
# 2399998        foreign  s23_nospendinflow  s23_nospendinflow_foreign
# 2399999        foreign  s24_nospendinflow  s24_nospendinflow_foreign
#
#            recipient_sector_region       spend
# 0            s_s01_spendinflow_101  51469948.0
# 1            s_s01_spendinflow_101  25137598.0
# 2            s_s01_spendinflow_101  11569621.0
# 3            s_s01_spendinflow_101  78666368.0
# 4            s_s01_spendinflow_101   9757826.0
# ...                            ...         ...
# 2399995  s_s10_spendinflow_foreign         NaN
# 2399996  s_s10_spendinflow_foreign         NaN
# 2399997  s_s10_spendinflow_foreign         NaN
# 2399998  s_s10_spendinflow_foreign         NaN
# 2399999  s_s10_spendinflow_foreign         NaN
#
# [2400000 rows x 5 columns]

# %%
df_new['recipient_region'] = df_new['recipient_sector_region'].str.extract(r'spendinflow_(.+)$')
df_new['recipient_sector'] = df_new['recipient_sector_region'].str.extract(r'(.+)_.+$')
df_new
# Out:
#         spender_region     spender_sector      spender_sector_region  \
# 0                  101    s01_spendinflow        s01_spendinflow_101
# 1                  101    s02_spendinflow        s02_spendinflow_101
# 2                  101    s03_spendinflow        s03_spendinflow_101
# 3                  101    s04_spendinflow        s04_spendinflow_101
# 4                  101    s05_spendinflow        s05_spendinflow_101
# ...                ...                ...                        ...
# 2399995        foreign  s20_nospendinflow  s20_nospendinflow_foreign
# 2399996        foreign  s21_nospendinflow  s21_nospendinflow_foreign
# 2399997        foreign  s22_nospendinflow  s22_nospendinflow_foreign
# 2399998        foreign  s23_nospendinflow  s23_nospendinflow_foreign
# 2399999        foreign  s24_nospendinflow  s24_nospendinflow_foreign
#
#            recipient_sector_region       spend recipient_region  \
# 0            s_s01_spendinflow_101  51469948.0              101
# 1            s_s01_spendinflow_101  25137598.0              101
# 2            s_s01_spendinflow_101  11569621.0              101
# 3            s_s01_spendinflow_101  78666368.0              101
# 4            s_s01_spendinflow_101   9757826.0              101
# ...                            ...         ...              ...
# 2399995  s_s10_spendinflow_foreign         NaN          foreign
# 2399996  s_s10_spendinflow_foreign         NaN          foreign
# 2399997  s_s10_spendinflow_foreign         NaN          foreign
# 2399998  s_s10_spendinflow_foreign         NaN          foreign
# 2399999  s_s10_spendinflow_foreign         NaN          foreign
#
#           recipient_sector
# 0        s_s01_spendinflow
# 1        s_s01_spendinflow
# 2        s_s01_spendinflow
# 3        s_s01_spendinflow
# 4        s_s01_spendinflow
# ...                    ...
# 2399995  s_s10_spendinflow
# 2399996  s_s10_spendinflow
# 2399997  s_s10_spendinflow
# 2399998  s_s10_spendinflow
# 2399999  s_s10_spendinflow
#
# [2400000 rows x 7 columns]

# %%
df_new[df_new['spender_sector_region']=='s24_nospendinflow_foreign'] # Test
# Out:
#         spender_region     spender_sector      spender_sector_region  \
# 2399           foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 4799           foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 7199           foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 9599           foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 11999          foreign  s24_nospendinflow  s24_nospendinflow_foreign
# ...                ...                ...                        ...
# 2390399        foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 2392799        foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 2395199        foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 2397599        foreign  s24_nospendinflow  s24_nospendinflow_foreign
# 2399999        foreign  s24_nospendinflow  s24_nospendinflow_foreign
#
#            recipient_sector_region  spend recipient_region   recipient_sector
# 2399         s_s01_spendinflow_101    NaN              101  s_s01_spendinflow
# 4799         s_s01_spendinflow_147    NaN              147  s_s01_spendinflow
# 7199         s_s01_spendinflow_151    NaN              151  s_s01_spendinflow
# 9599         s_s01_spendinflow_153    NaN              153  s_s01_spendinflow
# 11999        s_s01_spendinflow_155    NaN              155  s_s01_spendinflow
# ...                            ...    ...              ...                ...
# 2390399      s_s10_spendinflow_846    NaN              846  s_s10_spendinflow
# 2392799      s_s10_spendinflow_849    NaN              849  s_s10_spendinflow
# 2395199      s_s10_spendinflow_851    NaN              851  s_s10_spendinflow
# 2397599      s_s10_spendinflow_860    NaN              860  s_s10_spendinflow
# 2399999  s_s10_spendinflow_foreign    NaN          foreign  s_s10_spendinflow
#
# [1000 rows x 7 columns]

# %%
df_new['spender_sector'] = df_new['spender_sector'].str[1:3]
df_new['recipient_sector'] = df_new['recipient_sector'].str[3:5]
df_new
# Out:
#         spender_region spender_sector      spender_sector_region  \
# 0                  101             01        s01_spendinflow_101
# 1                  101             02        s02_spendinflow_101
# 2                  101             03        s03_spendinflow_101
# 3                  101             04        s04_spendinflow_101
# 4                  101             05        s05_spendinflow_101
# ...                ...            ...                        ...
# 2399995        foreign             20  s20_nospendinflow_foreign
# 2399996        foreign             21  s21_nospendinflow_foreign
# 2399997        foreign             22  s22_nospendinflow_foreign
# 2399998        foreign             23  s23_nospendinflow_foreign
# 2399999        foreign             24  s24_nospendinflow_foreign
#
#            recipient_sector_region       spend recipient_region  \
# 0            s_s01_spendinflow_101  51469948.0              101
# 1            s_s01_spendinflow_101  25137598.0              101
# 2            s_s01_spendinflow_101  11569621.0              101
# 3            s_s01_spendinflow_101  78666368.0              101
# 4            s_s01_spendinflow_101   9757826.0              101
# ...                            ...         ...              ...
# 2399995  s_s10_spendinflow_foreign         NaN          foreign
# 2399996  s_s10_spendinflow_foreign         NaN          foreign
# 2399997  s_s10_spendinflow_foreign         NaN          foreign
# 2399998  s_s10_spendinflow_foreign         NaN          foreign
# 2399999  s_s10_spendinflow_foreign         NaN          foreign
#
#         recipient_sector
# 0                     01
# 1                     01
# 2                     01
# 3                     01
# 4                     01
# ...                  ...
# 2399995               10
# 2399996               10
# 2399997               10
# 2399998               10
# 2399999               10
#
# [2400000 rows x 7 columns]

# %%
df_new = df_new.reindex(columns=['spender_region', 'spender_sector', 'recipient_region', 'recipient_sector',
                                 'spender_sector_region', 'recipient_sector_region', 'spend'])
df_new
# Out:
#         spender_region spender_sector recipient_region recipient_sector  \
# 0                  101             01              101               01
# 1                  101             02              101               01
# 2                  101             03              101               01
# 3                  101             04              101               01
# 4                  101             05              101               01
# ...                ...            ...              ...              ...
# 2399995        foreign             20          foreign               10
# 2399996        foreign             21          foreign               10
# 2399997        foreign             22          foreign               10
# 2399998        foreign             23          foreign               10
# 2399999        foreign             24          foreign               10
#
#              spender_sector_region    recipient_sector_region       spend
# 0              s01_spendinflow_101      s_s01_spendinflow_101  51469948.0
# 1              s02_spendinflow_101      s_s01_spendinflow_101  25137598.0
# 2              s03_spendinflow_101      s_s01_spendinflow_101  11569621.0
# 3              s04_spendinflow_101      s_s01_spendinflow_101  78666368.0
# 4              s05_spendinflow_101      s_s01_spendinflow_101   9757826.0
# ...                            ...                        ...         ...
# 2399995  s20_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399996  s21_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399997  s22_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399998  s23_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399999  s24_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
#
# [2400000 rows x 7 columns]

# %%
# Part 2: Convert region codes into actual region names

# %%
region_names = pd.read_excel(r"C:\Users\jasonjia\Dropbox\Projects\denmark_spending\data\dk_municipalities_code_to_name.xlsx")

# %%
region_names.shape
# Out:
# (99, 2)

# %%
region_names.head()
# Out:
#    Code           Name
# 0   101      København
# 1   147  Frederiksberg
# 2   151       Ballerup
# 3   153        Brøndby
# 4   155         Dragør

# %%
region_names = region_names.append({'Code': 'foreign', 'Name': 'foreign'}, ignore_index=True)

# %%
region_names
# Out:
#        Code           Name
# 0       101      København
# 1       147  Frederiksberg
# 2       151       Ballerup
# 3       153        Brøndby
# 4       155         Dragør
# ..      ...            ...
# 95      846  Mariagerfjord
# 96      849     Jammerbugt
# 97      851        Aalborg
# 98      860       Hjørring
# 99  foreign        foreign
#
# [100 rows x 2 columns]

# %%
region_names['Code'].dtype
# Out:
# dtype('O')

# %%
region_names['Code'] = region_names['Code'].astype('str')
region_names['Code'].dtype
# Out:
# dtype('O')

# %%
df_new['spender_region'].dtype
# Out:
# dtype('O')

# %%
df_new_names = df_new.merge(region_names, left_on='spender_region', right_on='Code', how='left')
df_new_names
# Out:
#         spender_region spender_sector recipient_region recipient_sector  \
# 0                  101             01              101               01
# 1                  101             02              101               01
# 2                  101             03              101               01
# 3                  101             04              101               01
# 4                  101             05              101               01
# ...                ...            ...              ...              ...
# 2399995        foreign             20          foreign               10
# 2399996        foreign             21          foreign               10
# 2399997        foreign             22          foreign               10
# 2399998        foreign             23          foreign               10
# 2399999        foreign             24          foreign               10
#
#              spender_sector_region    recipient_sector_region       spend  \
# 0              s01_spendinflow_101      s_s01_spendinflow_101  51469948.0
# 1              s02_spendinflow_101      s_s01_spendinflow_101  25137598.0
# 2              s03_spendinflow_101      s_s01_spendinflow_101  11569621.0
# 3              s04_spendinflow_101      s_s01_spendinflow_101  78666368.0
# 4              s05_spendinflow_101      s_s01_spendinflow_101   9757826.0
# ...                            ...                        ...         ...
# 2399995  s20_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399996  s21_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399997  s22_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399998  s23_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399999  s24_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
#
#             Code       Name
# 0            101  København
# 1            101  København
# 2            101  København
# 3            101  København
# 4            101  København
# ...          ...        ...
# 2399995  foreign    foreign
# 2399996  foreign    foreign
# 2399997  foreign    foreign
# 2399998  foreign    foreign
# 2399999  foreign    foreign
#
# [2400000 rows x 9 columns]

# %%
df_new_names = df_new_names.rename(columns = {'Name':'spender_region_name'})
df_new_names = df_new_names.drop(['Code'], axis = 1)
df_new_names
# Out:
#         spender_region spender_sector recipient_region recipient_sector  \
# 0                  101             01              101               01
# 1                  101             02              101               01
# 2                  101             03              101               01
# 3                  101             04              101               01
# 4                  101             05              101               01
# ...                ...            ...              ...              ...
# 2399995        foreign             20          foreign               10
# 2399996        foreign             21          foreign               10
# 2399997        foreign             22          foreign               10
# 2399998        foreign             23          foreign               10
# 2399999        foreign             24          foreign               10
#
#              spender_sector_region    recipient_sector_region       spend  \
# 0              s01_spendinflow_101      s_s01_spendinflow_101  51469948.0
# 1              s02_spendinflow_101      s_s01_spendinflow_101  25137598.0
# 2              s03_spendinflow_101      s_s01_spendinflow_101  11569621.0
# 3              s04_spendinflow_101      s_s01_spendinflow_101  78666368.0
# 4              s05_spendinflow_101      s_s01_spendinflow_101   9757826.0
# ...                            ...                        ...         ...
# 2399995  s20_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399996  s21_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399997  s22_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399998  s23_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399999  s24_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
#
#         spender_region_name
# 0                 København
# 1                 København
# 2                 København
# 3                 København
# 4                 København
# ...                     ...
# 2399995             foreign
# 2399996             foreign
# 2399997             foreign
# 2399998             foreign
# 2399999             foreign
#
# [2400000 rows x 8 columns]

# %%
df_new_names = df_new_names.merge(region_names, left_on='recipient_region', right_on='Code', how='left')
df_new_names
# Out:
#         spender_region spender_sector recipient_region recipient_sector  \
# 0                  101             01              101               01
# 1                  101             02              101               01
# 2                  101             03              101               01
# 3                  101             04              101               01
# 4                  101             05              101               01
# ...                ...            ...              ...              ...
# 2399995        foreign             20          foreign               10
# 2399996        foreign             21          foreign               10
# 2399997        foreign             22          foreign               10
# 2399998        foreign             23          foreign               10
# 2399999        foreign             24          foreign               10
#
#              spender_sector_region    recipient_sector_region       spend  \
# 0              s01_spendinflow_101      s_s01_spendinflow_101  51469948.0
# 1              s02_spendinflow_101      s_s01_spendinflow_101  25137598.0
# 2              s03_spendinflow_101      s_s01_spendinflow_101  11569621.0
# 3              s04_spendinflow_101      s_s01_spendinflow_101  78666368.0
# 4              s05_spendinflow_101      s_s01_spendinflow_101   9757826.0
# ...                            ...                        ...         ...
# 2399995  s20_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399996  s21_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399997  s22_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399998  s23_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399999  s24_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
#
#         spender_region_name     Code       Name
# 0                 København      101  København
# 1                 København      101  København
# 2                 København      101  København
# 3                 København      101  København
# 4                 København      101  København
# ...                     ...      ...        ...
# 2399995             foreign  foreign    foreign
# 2399996             foreign  foreign    foreign
# 2399997             foreign  foreign    foreign
# 2399998             foreign  foreign    foreign
# 2399999             foreign  foreign    foreign
#
# [2400000 rows x 10 columns]

# %%
df_new_names = df_new_names.rename(columns = {'Name':'recipient_region_name'})
df_new_names = df_new_names.drop(['Code'], axis = 1)
df_new_names
# Out:
#         spender_region spender_sector recipient_region recipient_sector  \
# 0                  101             01              101               01
# 1                  101             02              101               01
# 2                  101             03              101               01
# 3                  101             04              101               01
# 4                  101             05              101               01
# ...                ...            ...              ...              ...
# 2399995        foreign             20          foreign               10
# 2399996        foreign             21          foreign               10
# 2399997        foreign             22          foreign               10
# 2399998        foreign             23          foreign               10
# 2399999        foreign             24          foreign               10
#
#              spender_sector_region    recipient_sector_region       spend  \
# 0              s01_spendinflow_101      s_s01_spendinflow_101  51469948.0
# 1              s02_spendinflow_101      s_s01_spendinflow_101  25137598.0
# 2              s03_spendinflow_101      s_s01_spendinflow_101  11569621.0
# 3              s04_spendinflow_101      s_s01_spendinflow_101  78666368.0
# 4              s05_spendinflow_101      s_s01_spendinflow_101   9757826.0
# ...                            ...                        ...         ...
# 2399995  s20_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399996  s21_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399997  s22_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399998  s23_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
# 2399999  s24_nospendinflow_foreign  s_s10_spendinflow_foreign         NaN
#
#         spender_region_name recipient_region_name
# 0                 København             København
# 1                 København             København
# 2                 København             København
# 3                 København             København
# 4                 København             København
# ...                     ...                   ...
# 2399995             foreign               foreign
# 2399996             foreign               foreign
# 2399997             foreign               foreign
# 2399998             foreign               foreign
# 2399999             foreign               foreign
#
# [2400000 rows x 9 columns]

# %%
df_new_names = df_new_names.reindex(columns=['spender_region', 'spender_region_name', 'spender_sector', 
                                 'recipient_region', 'recipient_region_name', 'recipient_sector',
                                 'spender_sector_region', 'recipient_sector_region', 'spend'])
df_new_names
# Out:
#         spender_region spender_region_name spender_sector recipient_region  \
# 0                  101           København             01              101
# 1                  101           København             02              101
# 2                  101           København             03              101
# 3                  101           København             04              101
# 4                  101           København             05              101
# ...                ...                 ...            ...              ...
# 2399995        foreign             foreign             20          foreign
# 2399996        foreign             foreign             21          foreign
# 2399997        foreign             foreign             22          foreign
# 2399998        foreign             foreign             23          foreign
# 2399999        foreign             foreign             24          foreign
#
#         recipient_region_name recipient_sector      spender_sector_region  \
# 0                   København               01        s01_spendinflow_101
# 1                   København               01        s02_spendinflow_101
# 2                   København               01        s03_spendinflow_101
# 3                   København               01        s04_spendinflow_101
# 4                   København               01        s05_spendinflow_101
# ...                       ...              ...                        ...
# 2399995               foreign               10  s20_nospendinflow_foreign
# 2399996               foreign               10  s21_nospendinflow_foreign
# 2399997               foreign               10  s22_nospendinflow_foreign
# 2399998               foreign               10  s23_nospendinflow_foreign
# 2399999               foreign               10  s24_nospendinflow_foreign
#
#            recipient_sector_region       spend
# 0            s_s01_spendinflow_101  51469948.0
# 1            s_s01_spendinflow_101  25137598.0
# 2            s_s01_spendinflow_101  11569621.0
# 3            s_s01_spendinflow_101  78666368.0
# 4            s_s01_spendinflow_101   9757826.0
# ...                            ...         ...
# 2399995  s_s10_spendinflow_foreign         NaN
# 2399996  s_s10_spendinflow_foreign         NaN
# 2399997  s_s10_spendinflow_foreign         NaN
# 2399998  s_s10_spendinflow_foreign         NaN
# 2399999  s_s10_spendinflow_foreign         NaN
#
# [2400000 rows x 9 columns]

# %%
df_new_names[(df_new_names['recipient_sector_region']=='s_s10_spendinflow_846') & (df_new_names['spender_sector']=='20')] # Test
# Out:
#         spender_region spender_region_name spender_sector recipient_region  \
# 2388019            101           København             20              846
# 2388043            147       Frederiksberg             20              846
# 2388067            151            Ballerup             20              846
# 2388091            153             Brøndby             20              846
# 2388115            155              Dragør             20              846
# ...                ...                 ...            ...              ...
# 2390299            846       Mariagerfjord             20              846
# 2390323            849          Jammerbugt             20              846
# 2390347            851             Aalborg             20              846
# 2390371            860            Hjørring             20              846
# 2390395        foreign             foreign             20              846
#
#         recipient_region_name recipient_sector      spender_sector_region  \
# 2388019         Mariagerfjord               10      s20_nospendinflow_101
# 2388043         Mariagerfjord               10      s20_nospendinflow_147
# 2388067         Mariagerfjord               10      s20_nospendinflow_151
# 2388091         Mariagerfjord               10      s20_nospendinflow_153
# 2388115         Mariagerfjord               10      s20_nospendinflow_155
# ...                       ...              ...                        ...
# 2390299         Mariagerfjord               10      s20_nospendinflow_846
# 2390323         Mariagerfjord               10      s20_nospendinflow_849
# 2390347         Mariagerfjord               10      s20_nospendinflow_851
# 2390371         Mariagerfjord               10      s20_nospendinflow_860
# 2390395         Mariagerfjord               10  s20_nospendinflow_foreign
#
#         recipient_sector_region          spend
# 2388019   s_s10_spendinflow_846    8663.074219
# 2388043   s_s10_spendinflow_846    6779.158203
# 2388067   s_s10_spendinflow_846            NaN
# 2388091   s_s10_spendinflow_846            NaN
# 2388115   s_s10_spendinflow_846            NaN
# ...                         ...            ...
# 2390299   s_s10_spendinflow_846  110106.906250
# 2390323   s_s10_spendinflow_846            NaN
# 2390347   s_s10_spendinflow_846    4674.045410
# 2390371   s_s10_spendinflow_846            NaN
# 2390395   s_s10_spendinflow_846            NaN
#
# [100 rows x 9 columns]

# %%
df_new_names.to_csv(r"C:\Users\jasonjia\Dropbox\Projects\denmark_spending\data\spending_matrix_processed.csv", index=False)
